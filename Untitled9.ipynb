# %% [markdown]
# <a href="https://colab.research.google.com/github/YuzuMallzz/Algoritma-Pemrograman/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Algoritma pemrograman
#
#  Apa itu Algoritma
#   Algoritma pemrograman
#    Apa itu Algoritma -Algoritma adalah uruten langkah langkah logis yg digunakan untuk menyelesaikan masalah -Algoritma adalah dasar dari pemrograman komputer Membantu menyelesaikan masalah secara efisien
#
#   Definisi Program
#   -Adalah kumpulan Instruksi-Instruksi tersendiri biasanya disebut source code yang dibuat oleh praglomer Paradigma .
#
#  1.  Paradigma Pemrograman
#  -Pemrograman prosedural
#  -Berdasarkan urutan-urutan, sekuensial
#  - program adalah suatu pang kaian prosedur untuk memanipulasi data. Prosedur merupakan kumpulan Instruksi Yang Di Kerjakan secara berurutan
#
#   2. Pemrograman Fungsional
#   -Berdasarkan teori Fungsi matematika
#   -Fungsi merupakan dasar utama program
#
#   3. Pemrograman Terstruktur
#    - Secara berurutan dan terstruktur
#    - Program dapat dibagi-bagi menjadi: prosedur dan puigs -contoh Pascal dan c
#
#    4. pemrograman Moduler
#     -pemrograman ini membentuk banyak modul
#     - modul merupakan kumpulan dari prosedur dan Fungsi yg berdiri sendiri -contoh: Modula -2 atau ADA.
#
#     5.Pemrograman Berorientasi objek
#      -pemrograman berdasarkan prinsip obyek memiliki data/variabel/property dan method /event/prosedur yg dapat Dimanipulasi
#      -contoh C++, object Pascal dan Java
#
#      6. pemrograman berorientasi fungsi - Pemrograman Ini berfokus pada suatu fungsi tertentu saja.
#      -contoh: SQL, HTML, xml dan lain lain
#
#      7. Pemrograman Deklaratif
#      -pemrograman ini mendeskripsikan Suatu masalah dengan Pernyataan daripada memecahkan masalah dengan Implementasi Algoritma -contoh:Prolog
#
#      Struktur sistem komputer:
#
#      ![WhatsApp Image 2024-10-12 at 09.21.36_a093d8b3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-10-12 at 09.51.28_e38263a6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Dilihat dari struktur sistem komputer dan siklos dintel Pemrograman den strukturdata menepati posisi hadirn Implimentosi katrnebagian Implimentisi bagian dim.. Pemrograman melakukan proses coding.
#
# sejarah Algoritma
#
# Asal kata Algoritma berasal dari nama Abu Jafar Mohammed Ibn Musa Al-khowarizmi Ilmuan Persia yang menulis. kitab Al Jabr Wa Al Mulabala [Rules Of Restoration]pada tahun 825M
#
# Definisi Algoritma
#
# -Algoritma adalah urutan langkah logis tertentu untuk memecahkan suatu masalah. Algoritma harus mengikuta Suatu urutan tertentu, tidak boleh melom Pet-lompat
# - Alur pemikiran dalam menyelesaikan suatu perkerjaan yang di tuangkan secara tertulis. yang ditekankan pertama adalah Alur Pikiran. Sedangkan penekanan kedua Adalah tertulis, yang artinya dapat berupa gambar-kalimat atau tabel tertentu
#
# Asal usul Algoritma
#
# a.Kata Algoritme berasal dari name seorang Ahli Matematika Persia. Abu Abdullah Muhammad Ibn Musa Al Khwarizmi yang hidup Pada abad ke 9
#
# b. Nama Al-Khwarizmi mengalami perubahan Foretis dieropa pada abad Pertengahan menjadi "Algoritmi"
#
# 2 Algoritma di dunia kuno.
#
# a. Algoritma baru muncul pada abad 9 konsep Pemecahan masalah melalui langkah-langkah sistematis
#
# b. Tabel perhitungan babilonia (Sekitar 1600SM).
#
# c. Eucis abad ke 3SM menyusun Algoritma yang terkenal untuk menemukan pembagi terbesar dua bilangan
#
# d. Archimedes juga menggunakan Algoritma delam karya nya
#
# 3 Algoritma dalam matematika klesik
#
# a. Pada abad pertengahan dan renaisans. Perkembangan
# Algoritma berfokus pada aritmatika.
#
# b. John Naiper, memperkenalkan logaritma Pada Awal abad ke 17
#
# c. Blaise Pascal dan GottFried wilhelm Lelbni 2 mengembangkan mesin mekanik berbasis Algoritma
#
# 4 Revolusi Algoritma dan Komputer
#
# A.revolusi Algoritma dimulai dengan penemuan mesin komputasi modern.charles babbage seorang matematikawan Inggris pada Abad ke 19و
#
# B. Ada lovelace seorang Ahli matematika Inggris. di anggap sebagai pragramer pertama di dunia merancang mesin analitik yang digunakan Untuk Menyelesaikan masalah.
#
# 5 Algoritme di Era komputasi modern
#
# A. Pada abad ke 20 perkembangan Ilmu komputer menciptakan kebutuhan besar akan Algoritme yangوlebih kompleks
#
# b. Alan Turing bapak Ilmu komputer modern Mengembangkan model komputasi teoritis yang di sebut mesir turing pada 1936
#
# c. John vou neuman merancang arsitektur kompotasi Yang mendukung eksekusi Algoritma
#
# 6 Perkembangan Algoritmadi dunia digital
#
# A.Algoritmo menjadi pusat dari berbagai Aplikas kom putasi modern
#
# B. Algoritma sorting seperti bubble Sort Quick Sort dan Merge Sort mulai dikembangkan untur mengatur data
#
# C.Pada 1950an-dan 19600m Doland Knuth menerbitkan buku The Art Of Komputer programing. Dia memperken banyak metode dan strategi optimasi Algoritme
#
# D.Algoritma kriptografi untuk mengamankan data dunia digital
#
# 7. Algoritma di Era Kecerdasan Buatan
#
# a. Pada abad ke-21, algoritma memegang peranan penting dalam perkembangan
#
# kecerdasan buatan (Ai), machine learning, dan big data.
#
# b. Algoritma Neural Networks dan Deep Learning memungkinkan komputer untuk "belajar" dari data dan membuat keputusan yang kompleks.
#
# c Penerapan algoritma pada search engines (Google), media sosial, hingga otomasi di berbagai industri membuat algoritma menjadi bagian tak terpisahkan dari kehidupan modern.
#
# 8. Masa Depan Algoritma
#
# a. Di masa depan, algoritma terus berkembang dengan peningkatan dalam komputasi kuantum, pengenalan pola, dan optimasi sistem kompleks.
#
# b. Algoritma tidak hanya berperan dalam komputerisasi tetapi juga dalam pemecahan masalah di bidang lain seperti medis, keuangan, dan robotik.
#
# Contoh Algoritma dalam kehidupan nyata:
#
# Jika seorang ingin memasak atau membuat kue, baik itu melihat resep ataupun tidak pasti akan melakukan suatu langkah-langkah tertentu sehingga masakannya ataukuenya jadi.
#
# Jika seseorang ingin mengirim surat kepada kenalannya di tempat lain, langkah yang harus dilakukan adalah:
#
#  -Menulis surat
#
#  -Surat dimasukkan ke dalam amplop tertutup
#
# Amplop ditempeli perangko secukupnya.
#
#  -Pergi ke Kantor Pos terdekat untuk mengirimkannya.
#
# Dalam bidang komputer, algoritma sangat diperlukan dalam menyelesaikan berbagai masalah pemrograman, terutama dalam komputasi numeris. Tanpa algoritma yang dirancangbaik maka proses pemrograman akan menjadi salah, rusak, atau lambat dan tidak efisien.
#
# Pelaksana algoritma adalah Komputer.
#
# Manusia dan komputer berkomunikasi dengan cara: manusia memberikan perintah-perintah kepada komputer berupa instruksi-instruksi yang disebut program.
#
# Alat yang digunakan untuk membuat program tersebut adalah bahasa pemrograman. Bahasa pemrograman sangat bermacam-macam: C, C++, Pascal, Java, C#, Basic, Perl, PHP, ASP, JSP, J#, J++ dan masih banyak bahasa lainnya. Dari berbagai bahasa pemrograman cara memberikan instruksinya berbeda-beda namun bertujuan menghasilkan output yang sama.
#
# Kriteria Algoritma Menurut Donald E. Knuth
#
# 1. Input: algoritma dapat memiliki nol atau lebih inputan dari luar.
#
# 2. Output: algoritma harus memiliki minimal satu buah output keluaran.
#
# 3. Definiteness (pasti): algoritma memiliki instruksi-instruksi yang jelas dan tidak
#
# ambigu.
#
# 4. Finiteness (ada batas): algoritma harus memiliki titik berhenti (stopping role).
#
# 5. Effectiveness (tepat dan efisien): algoritma sebisa mungkin harus dapat dilaksanakandan efektif. Contoh instruksi yang tidak efektif adalah: A = A + 0 atau A = A*1
#
# Namun ada beberapa program yang memang dirancang untuk unterminatable: contoh SistemOperasi
#
# Jenis Proses Algoritma
#
# 1. Sequence Process: instruksi dikerjakan secara sekuensial, berurutan.
#
# 2. Selection Process: instruksi dikerjakan jika memenuhi kriteria tertentu
#
# 3. Iteration Process: instruksi dikerjakan selama memenuhi suatu kondisi tertentu.
#
# 4. Concurrent Process: beberapa instruksi dikerjakan secara bersama.
#
# Langkah Penyusunan Algoritma
#
# Judul: Langkah-langkah Menyusun Algoritma Konten:
#
# 1. Identifikasi masalah.
#
# 2. Tentukan input dan output.
#
# 3. Definisikan langkah-langkah dalam urutan logis.
#
# 4. Periksa solusi untuk memastikan hasil yang diinginkan..
#
# Contoh Algoritma
#
# Algoritma menghitung luas persegi panjang:
#
# 1. Masukkan panjang (P)
#
# 2. Masukkan lebar (L)
#
# 3. L-P*L
#
# 4. Tulis L
#
# Kesimpulan
#
# 1. Algoritma membantu menyelesaikan masalah dengan pendekatan sistematis.
#
# 2. Penting untuk mendefinisikan langkah dengan jelas untuk efisiensi.
#
# 3. Algoritma adalah inti dari pengembangan perangkat lunak yang efisien.

# %% [markdown]
#  1.Siapa tokoh yg menjadi asal usul dari Istilah "Algoritma".. dan Apa kontribusi utamanya dalam perkembangan ilmu Matematika ?
#
# tokoh yang menjadi asal usul adalah muhammad lbn Musa Al Khwarizmi konstribusinya Pada perkembangan Ilmu matematika dalam bidang Aljabar, Aritmatika dan Algoritma
#
# 2.Algoritma eucid adalah salah Satu Algoritma yang paling awal yang masih digunakan hingga saat ini untuk Apa Algoritma ini di gunakan? untuk menemukan pembagi terbesar bilangen
#
# 3 siapa yang di anggap sebagal programer pertama didunia dan mesin komputasi apa yang ia bantu deskripsikan untuk menjalankan Algoritma? Ada lovelence, Algoritme pemrograman/mesin analitical
#
# 4.Apa konstribusi utama alan turing dalam sejarah Algoritma dan konsep penting yang di perkenalkan nya dalam teori komputasi?
# mengembangkan model komputasi Horitis yg disebut mesin turing mengkonseptualisasilkan ide bahwa setiap proses komputasi dapat dipecah menjadi serangkaian langkah langkah Algoritmis
#
# 5 Algoritma apa yg banyak digunakan dalam kecerdasan buatan dan machine learning untuk mengerjakan mesin mengenali pola dari data? meurel networks dan deep learning
